# %% [markdown]
# ## Highly divisible triangular number
#
# Problem 12
#
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
#
#      1: 1
#      3: 1,3
#      6: 1,2,3,6
#     10: 1,2,5,10
#     15: 1,3,5,15
#     21: 1,3,7,21
#     28: 1,2,4,7,14,28
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?
#
#
# Link: https://projecteuler.net/problem=12
#
# Date solved:
# 2022/03/06

# %%
# imports
import sys
sys.path.append('../../modules')

from sequences_compound import Triangle_Numbers_Prime_Factorization
from maths import divisor_count_from_pf_counter
from primes import num_from_pf_counter

# %%
# %%timeit # results = 
# solution

div_min = 500

TPF = Triangle_Numbers_Prime_Factorization()
valids = TPF.take_while(lambda x: divisor_count_from_pf_counter(x)<div_min)
num_from_pf_counter(TPF[len(valids)])
# Out:
# 76576500

# %% [markdown]
# ## ANSWER = 76576500

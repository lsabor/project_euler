# %% [markdown]
# ## Highly divisible triangular number
#
# Problem 12
#
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
#
#      1: 1
#      3: 1,3
#      6: 1,2,3,6
#     10: 1,2,5,10
#     15: 1,3,5,15
#     21: 1,3,7,21
#     28: 1,2,4,7,14,28
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?
#
#
# Link: https://projecteuler.net/problem=12
#
# Date solved:
# 2022/03/06

# %%
# imports
import sys
sys.path.append('../modules')

import sequences_compound
import maths
import primes

# %%
# %%timeit # results = 
# solution

div_min = 500

TPF = sequences_compound.Triangle_Numbers_Prime_Factorization()
valids = TPF.take_while(lambda x: maths.divisor_count_from_pf(x)<div_min)
primes.num_from_pf_counter(TPF[len(valids)])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\lukes\OneDrive\Documents\coding\project_euler\0000s\0012.ipynb Cell 3' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/lukes/OneDrive/Documents/coding/project_euler/0000s/0012.ipynb#ch0000002?line=3'>4</a> div_min = 500
#       <a href='vscode-notebook-cell:/c%3A/Users/lukes/OneDrive/Documents/coding/project_euler/0000s/0012.ipynb#ch0000002?line=5'>6</a> TPF = sequences_compound.Triangle_Numbers_Prime_Factorization()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lukes/OneDrive/Documents/coding/project_euler/0000s/0012.ipynb#ch0000002?line=6'>7</a> valids = TPF.take_while(lambda x: maths.divisor_count_from_pf(x)<div_min)
# ...

# %% [markdown]
# ## ANSWER =
